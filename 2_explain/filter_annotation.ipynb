# %%
import pandas as pd
import numpy as np
import re

# %%
tomtom = pd.read_csv("./tomtom.tsv", sep='\t', header=0, index_col=0, skipfooter=3, engine='python')
tomtom = tomtom[tomtom["q-value"]<0.1][["Target_ID", "q-value"]]
tomtom
# Out:
#                                      Target_ID   q-value
# Query_ID
# Motif_0          taipale-CGGACACAATC-Foxk1-DBD  0.080489
# Motif_0           taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_0                           yetfasco-855  0.080489
# Motif_0          taipale-ACGGACACAAT-Foxj3-DBD  0.088926
# Motif_2                        jaspar-PF0017.1  0.031326
# ...                                        ...       ...
# Motif_127                         homer-M01620  0.096370
# Motif_127                      jaspar-MA0320.1  0.096370
# Motif_127  taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127                        yetfasco-1202  0.096370
# Motif_127                        yetfasco-1272  0.096370
#
# [2020 rows x 2 columns]

# %%
anno = pd.read_csv("/media/ggj/Files/mount/NvWA_Final/TFBS/Dmel_scenic/motifs-v8-nr.flybase-m0.001-o0.0.tbl", 
                  sep='\t', header=0, index_col=0)
def f(x):
    x = x.replace('__', '-')
    x = re.sub(r"swissregulon-.+-", "swissregulon-", x) # swissregulon
#     m = re.match(r"^taipale-(.+?)_(.+?)_(.+?)$")
    if x.find("taipale") != -1:
        s = x.split("-")[1].split("_")
        if len(s) > 3:
            x = '-'.join(["taipale", s[2], s[0], s[1]])
    return x
anno.index = anno.index.map(lambda x: f(x))
anno = anno[["motif_name", "gene_name"]]
anno
# Out:
#                          motif_name gene_name
# #motif_id
# bergman-Abd-B                 Abd-B     Abd-B
# bergman-Adf1                   Adf1      Adf1
# bergman-Aef1                   Aef1      Aef1
# bergman-Cf2                     Cf2       Cf2
# bergman-Dip3                   Dip3     Dlip3
# ...                             ...       ...
# yetfasco-YPR104C_2203  YPR104C_2203      FoxK
# yetfasco-YPR104C_2203  YPR104C_2203       bin
# yetfasco-YPR104C_2203  YPR104C_2203     fd19B
# yetfasco-YPR104C_2203  YPR104C_2203      slp1
# yetfasco-YPR104C_2203  YPR104C_2203      slp2
#
# [54676 rows x 2 columns]

# %%
# anno.source_name.unique()

# %%
# anno[anno.source_name=='yetfasco'].index.unique()

# %%
# anno.index.intersection(tomtom.Target_ID)

# %%
tomtom_anno = tomtom.merge(anno, how='left', left_on="Target_ID", right_index=True)
tomtom_anno
# Out:
#                                      Target_ID   q-value  \
# Query_ID
# Motif_0          taipale-CGGACACAATC-Foxk1-DBD  0.080489
# Motif_0           taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_0           taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_0                           yetfasco-855  0.080489
# Motif_0          taipale-ACGGACACAAT-Foxj3-DBD  0.088926
# ...                                        ...       ...
# Motif_127  taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127  taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127  taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127                        yetfasco-1202  0.096370
# Motif_127                        yetfasco-1272  0.096370
#
#                                  motif_name gene_name
# Query_ID
# Motif_0                                 NaN       NaN
# Motif_0           FOXK1_DBD_CGGACACAAT_repr      FoxK
# Motif_0           FOXK1_DBD_CGGACACAAT_repr      slp1
# Motif_0                                 NaN       NaN
# Motif_0                                 NaN       NaN
# ...                                     ...       ...
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr     Atac3
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets21C
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets97D
# Motif_127                               NaN       NaN
# Motif_127                               NaN       NaN
#
# [6879 rows x 4 columns]

# %%
tomtom_anno[tomtom_anno.motif_name.isna()].Target_ID.unique()
# Out:
# array(['taipale-CGGACACAATC-Foxk1-DBD', 'yetfasco-855',
#        'taipale-ACGGACACAAT-Foxj3-DBD', 'jaspar-PF0017.1',
#        'selexconsensus-tll', 'homer-M00359', 'yetfasco-460',
#        'yetfasco-1192', 'yetfasco-1201', 'yetfasco-1221', 'yetfasco-1193',
#        'yetfasco-1235', 'yetfasco-1240', 'yetfasco-1185', 'yetfasco-1243',
#        'yetfasco-1259', 'yetfasco-1265', 'encode-UW.Motif.0038',
#        'yetfasco-1263', 'yetfasco-1416', 'yetfasco-1207', 'yetfasco-1187',
#        'yetfasco-1222', 'wolfe-Sqz_SOLEXA_F1-3', 'yetfasco-1182',
#        'yetfasco-1249', 'yetfasco-1268', 'yetfasco-1264',
#        'wolfe-rn_SOLEXA_F2-4', 'jaspar-PF0060.1', 'yetfasco-1215',
#        'yetfasco-1174', 'yetfasco-1239', 'yetfasco-1209', 'yetfasco-48.3',
#        'homer-M00683', 'yetfasco-1261', 'wolfe-jim_F1-4_SOLEXA_2.5',
#        'yetfasco-1251', 'iDMMPMM-HB', 'yetfasco-1228', 'yetfasco-48.2',
#        'yetfasco-1257', 'yetfasco-1271', 'yetfasco-1245', 'yetfasco-1275',
#        'yetfasco-1223', 'yetfasco-1273', 'homer-M00133',
#        'taipale-TATGCAAAT-Pou2f2-DBD', 'homer-M00342',
#        'selexconsensus-pho', 'yetfasco-1277', 'yetfasco-974',
#        'jaspar-PF0033.1', 'tiffin-TIFDMEM0000002', 'yetfasco-956',
#        'swissregulon-PRRX1-2.p2', 'jaspar-CN0073.1', 'jaspar-CN0124.1',
#        'jaspar-PF0055.1', 'yetfasco-984', 'jaspar-CN0114.1',
#        'homer-M01590', 'jaspar-MA0290.1', 'yetfasco-301', 'yetfasco-611',
#        'homer-M01475', 'homer-M01751', 'homer-M01653', 'jaspar-MA0353.1',
#        'yetfasco-2083', 'yetfasco-650', 'homer-M01511', 'homer-M01818',
#        'yetfasco-1305', 'yetfasco-2048', 'yetfasco-2049', 'yetfasco-756',
#        'homer-M01652', 'jaspar-MA0352.1', 'yetfasco-485', 'yetfasco-244',
#        'yetfasco-214', 'yetfasco-235', 'yetfasco-1584', 'yetfasco-1589',
#        'yetfasco-924', 'taipale-GCTTTTCCCACA-ZNF75A-DBD',
#        'jaspar-PF0047.1', 'yetfasco-1104', 'jaspar-PF0148.1',
#        'jaspar-PF0088.1', 'yetfasco-1288', 'yetfasco-1184',
#        'yetfasco-1248', 'homer-M01798', 'jaspar-PF0092.1', 'yetfasco-659',
#        'taipale-AACAATANCATTGTT-SRY-DBD', 'jaspar-PF0049.1',
#        'taipale-NAACAATANCATTGTTN-SOX2-full',
#        'taipale-AACAATAMCATTGTT-SOX15-full',
#        'taipale-GGGGTCAAAGGTCA-RXRG-full',
#        'taipale-RRGTCCAAAGGTCAA-HNF4A-full',
#        'taipale-GGGGTCAAAGGTCA-RXRA-full',
#        'taipale-GGGGTCAAAGGTCA-RXRB-DBD', 'taipale-TCAATANCATTGA-SRY-DBD',
#        'taipale-RRGGTCAAAGGTCA-NR2F6-DBD',
#        'taipale-AACAATNNCATTGTT-SOX18-full',
#        'taipale-NRGTCCAAAGTCCANY-HNF4A-full',
#        'taipale-GGGGTCAAAGGTCA-RXRA-DBD',
#        'taipale-GGGGTCAAAGGTCA-RXRG-DBD',
#        'taipale-RRGGTCAAAGGTCA-Nr2f6-DBD',
#        'taipale-RRGGTCAAAGTCCRNN-Hnf4a-DBD',
#        'taipale-NAACAATNNNATTGTTN-SOX2-DBD',
#        'taipale-ATCAATAACATTGAT-SOX15-full',
#        'taipale-GGGGTCAAAGGTCA-Rxrb-DBD',
#        'taipale-RRGGTCAAAGTCCRNN-HNF4A-DBD',
#        'taipale-GGGGTCAAAGGTCA-Rxra-DBD',
#        'taipale-NRGGTCANNGGTCAN-NR2F1-DBD', 'jaspar-PF0071.1',
#        'taipale-ACAATANCATTG-SOX14-DBD', 'swissregulon-SOX_8-9-10_.p2',
#        'taipale-NACAATWNCATTGTN-Sox1-DBD',
#        'taipale-AACAATRTKCAGWGTT-SOX9-full', 'jaspar-PF0013.1',
#        'jaspar-PF0073.1', 'taipale-AACAATNNNCATTGTT-SRY-DBD',
#        'taipale-TCAATNNNATTGA-SOX21-DBD', 'homer-M00341',
#        'taipale-AACAATRTKCAGWGTT-SOX8-DBD',
#        'taipale-NNTTTTGGCGCCAAAANN-E2F3-DBD', 'homer-M01784',
#        'jaspar-PF0008.1', 'taipale-AATGGCGCCAAA-E2F4-DBD',
#        'taipale-TTTGGCGCCAAA-E2F4-DBD', 'yetfasco-592', 'homer-M01546',
#        'yetfasco-1313', 'homer-M01828',
#        'taipale-AAAAATGGCGCCAAAANN-E2F2-DBD',
#        'taipale-NNTTTTGGCGCCAAAANN-E2F2-DBD', 'yetfasco-1956',
#        'homer-M01548', 'homer-M00076', 'yetfasco-1116', 'yetfasco-48.1',
#        'yetfasco-368', 'homer-M01539', 'yetfasco-46', 'homer-M00212',
#        'hdpi-TP73', 'homer-M01510', 'homer-M01805', 'jaspar-PF0021.1',
#        'yetfasco-279', 'yetfasco-88', 'taipale-AAAAAGCGGAAGTN-SPI1-full',
#        'yetfasco-509', 'homer-M00334', 'yetfasco-1181', 'jaspar-PF0050.1',
#        'taipale-TGCCACGTCATCA-Creb3l2-DBD', 'homer-M01726',
#        'jaspar-MA0426.1', 'homer-M00403', 'yetfasco-422', 'homer-M01562',
#        'homer-M01846', 'homer-M00363', 'selexconsensus-eve',
#        'selexconsensus-zen', 'homer-M00329', 'yetfasco-677',
#        'jaspar-CN0122.1', 'homer-M00812', 'swissregulon-NKX6-1-2.p2',
#        'homer-M00462', 'stark-KCAATAAA', 'jaspar-PF0121.1',
#        'taipale-CCAATAAAAN-HOXB13-DBD', 'homer-M00744', 'homer-M00567',
#        'jaspar-PF0038.1', 'taipale-TCAAGGTCAWN-ESRRB-DBD',
#        'taipale-GRGGTCAAAAGKTCAC-RARG-full',
#        'taipale-GRGGTCAAAAGKTCAC-Rarg-DBD',
#        'taipale-AARGGTCAAAAGGTCA-Rarb-DBD',
#        'taipale-RRGGTCAAAAGGTCA-Rara-DBD', 'jaspar-CN0032.1',
#        'homer-M00554', 'jaspar-CN0104.1', 'taipale-NTCAAGGTCAN-ESRRA-DBD',
#        'taipale-TSAAGGTCAN-ESRRG-full',
#        'taipale-GRGGTCAAAAGGTCANA-RARG-DBD',
#        'taipale-ATGAATTGCAGTCAT-SOX10-full', 'swissregulon-NR5A1-2.p2',
#        'jaspar-PF0025.1', 'taipale-RRGGTCANNNRRGGTCA-Rarg-DBD',
#        'homer-M00827', 'jaspar-CN0082.1', 'jaspar-CN0030.1',
#        'taipale-ARGGTCAAAAGGTCA-RARA-full', 'homer-M01397',
#        'jaspar-MA0141.1', 'taipale-ATGAATTGCAGTCAT-Sox10-DBD',
#        'homer-M00132', 'jaspar-CN0140.1',
#        'taipale-ATGAATKNYAGTC-SOX8-DBD', 'encode-UW.Motif.0062',
#        'taipale-RAGGTCANTCAAGGTCA-ESRRG-full', 'jaspar-PF0174.1',
#        'taipale-RRGGTCANNNARAGGTCA-Rarg-DBD',
#        'taipale-NRAAGGTCAANNNNRGGTCA-RORA-DBD', 'homer-M01042',
#        'jaspar-PB0134.1', 'jaspar-PF0042.1',
#        'taipale-AAAAGTCAA-NR2E1-full', 'tiffin-TIFDMEM0000078',
#        'taipale-RRGGTCAAAAGGTCA-NR2F6-DBD',
#        'taipale-RGGTCANNNARRGGTCA-Rara-DBD', 'jaspar-CN0167.1',
#        'homer-M00961', 'jaspar-PB0053.1', 'yetfasco-285',
#        'taipale-RGGTCANNNARRGGTCA-Rarb-DBD',
#        'taipale-ATGAATKNYAGTC-SOX8-full',
#        'taipale-ARRGGTCANNNRRGGTCA-Rara-DBD',
#        'taipale-NATGAATKNYAGTCATN-SOX9-full',
#        'taipale-RRGGTCAAAGGTCA-NR2F6-full', 'jaspar-CN0075.1',
#        'elemento-AAGGTCA', 'homer-M00048', 'homer-M00922',
#        'jaspar-PB0014.1', 'homer-M00123', 'jaspar-CN0148.1',
#        'taipale-RRGGTCAAAAGGTCA-Nr2f6-DBD',
#        'taipale-AGGTGTGAAWTTCACACCT-TBX1-DBD',
#        'taipale-ARRGGTCANNNRRGGTCA-Rarb-DBD', 'jaspar-CN0199.1',
#        'homer-M00102', 'homer-M00957', 'jaspar-PB0049.1', 'yetfasco-2104',
#        'homer-M01380', 'jaspar-CN0172.1', 'jaspar-PF0075.1',
#        'homer-M01336', 'jaspar-MA0065.1',
#        'taipale-AACAATTGCAGTGTT-Sox10-DBD',
#        'taipale-AACAATTGCAGTGTT-Sox11-DBD', 'yetfasco-993',
#        'yetfasco-1154', 'yetfasco-30', 'taipale-RATAAAAR-CPEB1-full',
#        'yetfasco-989', 'swissregulon-FOXQ1.p2', 'jaspar-PF0051.1',
#        'taipale-NCTAWAAATAGM-MEF2D-DBD', 'taipale-CCAATAAAAN-HOXC13-DBD',
#        'homer-M01194', 'jaspar-PH0078.1', 'homer-M00017',
#        'taipale-RCTAWAAATAGM-MEF2B-full', 'yetfasco-1099',
#        'yetfasco-1326', 'jaspar-PF0036.1',
#        'taipale-CCAATAAAAN-HOXA13-full', 'yetfasco-1232',
#        'swissregulon-MEF2_A-B-C-D_.p2', 'taipale-CCAATAAAAN-Hoxd13-DBD',
#        'homer-M01647', 'jaspar-MA0347.1', 'homer-M01508', 'homer-M01844',
#        'yetfasco-788', 'yetfasco-2082', 'yetfasco-375', 'jaspar-PF0159.1',
#        'jaspar-PF0001.1', 'taipale-NACGCCCACGCANN-EGR1-full',
#        'homer-M00129', 'taipale-NACGCCCACGCANNN-Egr3-DBD',
#        'jaspar-PF0030.1', 'yetfasco-463', 'yetfasco-1084',
#        'taipale-NNACGCCCACGCANN-EGR3-DBD', 'yetfasco-1301',
#        'homer-M01456', 'jaspar-PL0018.1',
#        'taipale-AWCGAAACCGAAACY-IRF9-full',
#        'taipale-NCGAAACCGAAACYN-IRF4-full',
#        'taipale-NCGAAACCGAAACT-IRF8-full', 'jaspar-CN0024.1',
#        'taipale-CGCAGCTGCG-NHLH1-DBD', 'jaspar-PF0015.1',
#        'jaspar-PF0035.1', 'elemento-CAGCAGC', 'tfdimers-MD00570',
#        'taipale-CGCAGCTGCG-NHLH1-full', 'jaspar-CN0049.1',
#        'tiffin-TIFDMEM0000076', 'elemento-CAGCTGC', 'jaspar-PF0101.1',
#        'swissregulon-NHLH1-2.p2', 'homer-M00113', 'homer-M01323',
#        'jaspar-MA0048.1', 'jaspar-PF0012.1', 'jaspar-CN0086.1',
#        'elemento-CATCAGC', 'homer-M00198', 'homer-M00911',
#        'jaspar-PB0003.1', 'homer-M01495', 'elemento-CAGCTGCA',
#        'elemento-CTGCAGC', 'homer-M01440', 'jaspar-PL0002.1',
#        'homer-M00227', 'jaspar-CN0046.1', 'stark-CAGNNGCA',
#        'homer-M00027', 'yetfasco-96', 'elemento-CAGGAGC', 'homer-M01449',
#        'jaspar-PL0011.1', 'elemento-CACCTGC', 'tfdimers-MD00528',
#        'yetfasco-1711', 'homer-M00114', 'swissregulon-TCF4_dimer.p2',
#        'taipale-NGGCACGTGCCN-HES7-DBD', 'yetfasco-1226',
#        'taipale-RTAAACATMAACA-Foxj3-DBD', 'yetfasco-1260',
#        'yetfasco-1080', 'jaspar-PF0054.1', 'yetfasco-1266',
#        'yetfasco-1172', 'yetfasco-1274', 'yetfasco-1234', 'yetfasco-1229',
#        'yetfasco-1167', 'yetfasco-1203', 'yetfasco-1183',
#        'encode-UW.Motif.0034', 'yetfasco-1198', 'homer-M00571',
#        'yetfasco-973', 'yetfasco-985', 'yetfasco-1290', 'yetfasco-1291',
#        'yetfasco-1587', 'yetfasco-1592', 'yetfasco-1593', 'homer-M01858',
#        'jaspar-CN0130.1', 'homer-M01490', 'homer-M01491', 'homer-M01493',
#        'homer-M01857', 'homer-M01861', 'homer-M01614', 'jaspar-PF0005.1',
#        'homer-M01615', 'jaspar-MA0315.1', 'swissregulon-NFY_A-B-C_.p2',
#        'homer-M01492', 'homer-M01862', 'yetfasco-649', 'yetfasco-699',
#        'yetfasco-1536', 'homer-M00124', 'yetfasco-1205', 'homer-M01332',
#        'jaspar-MA0060.1', 'yetfasco-695', 'encode-UW.Motif.0088',
#        'yetfasco-980', 'jaspar-PF0104.1',
#        'taipale-NAACAATTKCAGTGTT-SOX4-DBD',
#        'taipale-AACAATNNNAGTGTT-SOX10-full',
#        'taipale-NAACAATKNYAGTGTTN-SOX8-DBD',
#        'taipale-AACAATKNYAGTGTT-SOX8-full',
#        'taipale-NAACAATKNYAGTGTTN-SOX9-full',
#        'taipale-NATCAATKNYAGTGATN-SOX8-full',
#        'taipale-ATCAATTGCAGTGAT-Sox10-DBD', 'jaspar-CN0078.1',
#        'jaspar-PF0132.1', 'taipale-NATCAATKNYAGTGATN-SOX8-DBD',
#        'wolfe-BCl6-F5_CG4360F2-3_SOLEXA_2.5',
#        'wolfe-Blimp-1-F1-CG4360F2-3_SOLEXA_2.5', 'jaspar-PF0129.1',
#        'homer-M01467', 'homer-M01557', 'homer-M01558', 'homer-M01559',
#        'homer-M01755', 'yetfasco-672', 'yetfasco-1041', 'yetfasco-1093',
#        'yetfasco-1097', 'yetfasco-329', 'yetfasco-1492', 'homer-M01579',
#        'jaspar-MA0279.1', 'yetfasco-327', 'yetfasco-938', 'homer-M01816',
#        'jaspar-CN0223.1', 'homer-M01471', 'yetfasco-1159',
#        'yetfasco-1152', 'jaspar-PF0061.1', 'homer-M01810', 'yetfasco-387',
#        'yetfasco-775', 'wolfe-lmd-F3-5_SOLEXA_5', 'homer-M01664',
#        'yetfasco-489', 'homer-M01644', 'jaspar-MA0344.1', 'yetfasco-502',
#        'yetfasco-518', 'homer-M01642', 'jaspar-PF0139.1',
#        'tfdimers-MD00060', 'yetfasco-111',
#        'wolfe-kenF1-CG4360_F2-3_SOLEXA_5',
#        'taipale-ANRTAAAYAAACA-FOXC1-DBD', 'homer-M00496',
#        'taipale-RTAAAYAAACA-FOXC2-DBD', 'homer-M00148', 'homer-M01173',
#        'jaspar-PH0057.1', 'taipale-GYAATWAAAN-Hoxc10-DBD',
#        'jaspar-PF0142.1', 'yetfasco-1124', 'homer-M00593', 'homer-M00556',
#        'tiffin-TIFDMEM0000104', 'taipale-GTAATAAAA-HOXD12-DBD',
#        'taipale-CCAATAAAAN-HOXA13-DBD', 'swissregulon-ONECUT1-2.p2',
#        'swissregulon-FOX_I1-J2_.p2', 'homer-M00768', 'jaspar-MA0216.1',
#        'taipale-NNAAAATCRATANN-ONECUT3-DBD', 'homer-M00787',
#        'swissregulon-FOXO1-3-4.p2', 'taipale-RTAAACARTAAACA-FOXJ3-DBD',
#        'elemento-AATAAAT', 'homer-M00512', 'tiffin-TIFDMEM0000061',
#        'jaspar-PF0011.1', 'taipale-AAAAAGMGGAAGTA-Spic-DBD',
#        'taipale-AAAAAGMGGAAGTN-SPIB-DBD', 'homer-M00159',
#        'taipale-KSYGGAAGTN-ETV6-full', 'yetfasco-1010', 'jaspar-PF0099.1',
#        'homer-M01485', 'jaspar-PF0003.1', 'homer-M01405',
#        'swissregulon-EWSR1-FLI1.p2', 'elemento-TCCTCCTC', 'yetfasco-865',
#        'taipale-ACCGGAWATCCGGT-FLI1-full',
#        'taipale-ACCGGAWATCCGGT-ERG-full', 'homer-M01625',
#        'jaspar-MA0325.1', 'yetfasco-521',
#        'taipale-ACCGGAWATCCGGN-FLI1-DBD', 'homer-M00321', 'homer-M01738',
#        'jaspar-MA0438.1', 'yetfasco-571', 'yetfasco-866', 'yetfasco-954',
#        'yetfasco-204', 'yetfasco-67', 'homer-M01820', 'yetfasco-671',
#        'jaspar-CN0087.1', 'jaspar-CN0080.1', 'hdpi-SSX3',
#        'jaspar-CN0126.1', 'taipale-TRATTGCAATYA-Lhx8-DBD', 'yetfasco-276',
#        'jaspar-CN0079.1', 'hdpi-BARX1', 'homer-M00577', 'yetfasco-1434',
#        'yetfasco-62', 'tiffin-TIFDMEM0000017', 'swissregulon-SRY.p2',
#        'homer-M01596', 'taipale-RTAAACATAAACA-FOXJ3-DBD',
#        'taipale-ATGAATAACATTCAT-SOX15-full', 'tfdimers-MD00572',
#        'encode-UW.Motif.0031', 'yetfasco-65',
#        'taipale-NAACAATRNYATTGTTN-Sox3-DBD',
#        'taipale-NAACAATKNYAKTGTTN-SOX7-full', 'yetfasco-1658',
#        'taipale-GTAAACAW-FOXO3-full', 'homer-M01318', 'yetfasco-835',
#        'tiffin-TIFDMEM0000084', 'homer-M00927', 'jaspar-PB0019.1',
#        'swissregulon-FOX_D1-D2_.p2', 'homer-M00312', 'homer-M00926',
#        'jaspar-PB0018.1', 'homer-M01479', 'yetfasco-830',
#        'taipale-WNWGTMAATATTRACWNW-FOXB1-DBD', 'tfdimers-MD00440',
#        'yetfasco-1284', 'yetfasco-1285', 'homer-M00925',
#        'jaspar-PB0017.1', 'homer-M01525', 'transfac_public-M00160',
#        'taipale-NRNWAAYRTTKNYN-FOXD2-DBD', 'encode-UW.Motif.0077',
#        'homer-M01317', 'jaspar-MA0040.1', 'yetfasco-906', 'yetfasco-948',
#        'yetfasco-1254', 'yetfasco-934', 'yetfasco-1985', 'yetfasco-1186',
#        'yetfasco-1033', 'yetfasco-1258', 'yetfasco-1211', 'yetfasco-1252',
#        'homer-M00344', 'selexconsensus-prd-HD',
#        'taipale-TAATYRATTA-PAX7-full', 'swissregulon-HOX_A6-A7-B6-B7_.p2',
#        'homer-M00082', 'jaspar-PF0046.1', 'homer-M01522', 'homer-M01791',
#        'yetfasco-424', 'yetfasco-600', 'jaspar-CN0174.1',
#        'jaspar-CN0137.1', 'tfdimers-MD00017', 'tfdimers-MD00286',
#        'homer-M01237', 'jaspar-PH0121.1', 'tfdimers-MD00326',
#        'homer-M01238', 'jaspar-PH0122.1', 'tfdimers-MD00116',
#        'encode-UW.Motif.0148', 'homer-M01255', 'jaspar-PH0139.1',
#        'tfdimers-MD00450', 'homer-M01240', 'jaspar-PH0124.1',
#        'homer-M01239', 'jaspar-PH0123.1',
#        'taipale-TTTCAAGGCYCCC-PRDM4-full', 'yetfasco-1873',
#        'jaspar-PF0023.1', 'yetfasco-27',
#        'taipale-NTGMATAATTAATKAG-POU4F2-full', 'swissregulon-LHX3-4.p2',
#        'homer-M00489', 'homer-M01217', 'jaspar-PH0101.1', 'homer-M01209',
#        'jaspar-PH0093.1', 'homer-M00438', 'elemento-TAATTAA',
#        'homer-M00746', 'homer-M01269', 'jaspar-PH0153.1', 'homer-M00760',
#        'homer-M00453', 'homer-M01244', 'jaspar-PH0128.1', 'homer-M01211',
#        'jaspar-PH0095.1', 'homer-M01216', 'jaspar-PH0100.1',
#        'yetfasco-73', 'homer-M00724', 'homer-M01289', 'jaspar-PH0173.1',
#        'homer-M00792', 'homer-M01252', 'homer-M01265', 'jaspar-PH0136.1',
#        'jaspar-PH0149.1', 'homer-M00730', 'homer-M01127',
#        'jaspar-PH0011.1', 'homer-M01207', 'jaspar-PH0091.1',
#        'homer-M00810', 'homer-M01185', 'homer-M01262', 'homer-M01263',
#        'jaspar-PH0069.1', 'jaspar-PH0146.1', 'jaspar-PH0147.1',
#        'taipale-NRTTACGTAAYN-Dbp-DBD', 'homer-M00758',
#        'taipale-NTGMATAATTAATKAG-POU4F2-DBD', 'yetfasco-777',
#        'homer-M00503', 'taipale-NRTTACGTAAYN-Hlf-DBD', 'yetfasco-2092',
#        'homer-M01733', 'yetfasco-498', 'homer-M00782', 'tfdimers-MD00233',
#        'homer-M01234', 'homer-M01258', 'jaspar-PH0118.1',
#        'jaspar-PH0142.1', 'homer-M00459', 'homer-M01715',
#        'jaspar-MA0415.1', 'homer-M00718', 'homer-M00521', 'homer-M00461',
#        'homer-M01391', 'homer-M01266', 'jaspar-PH0150.1', 'homer-M00717',
#        'homer-M00435', 'homer-M00486', 'homer-M00733', 'yetfasco-662',
#        'yetfasco-1164', 'homer-M00726', 'homer-M00775', 'homer-M00776',
#        'homer-M00816', 'jaspar-MA0223.1', 'yetfasco-2074', 'homer-M01167',
#        'jaspar-PH0051.1', 'jaspar-CN0226.1',
#        'taipale-NRTTACGTAAYN-DBP-DBD', 'homer-M00743', 'homer-M00778',
#        'homer-M01292', 'jaspar-PH0176.1', 'homer-M00327',
#        'selexconsensus-en', 'jaspar-CN0120.1', 'homer-M01118',
#        'jaspar-PH0002.1', 'homer-M00719', 'homer-M01119', 'homer-M01175',
#        'homer-M01196', 'jaspar-PH0003.1', 'jaspar-PH0059.1',
#        'jaspar-PH0080.1', 'homer-M00777', 'homer-M01803', 'homer-M00480',
#        'homer-M00735', 'homer-M01473', 'taipale-NRTTACRTAAYN-TEF-DBD',
#        'tfdimers-MD00491', 'homer-M01719', 'jaspar-MA0419.1',
#        'homer-M00736', 'homer-M00780', 'homer-M01236', 'jaspar-PH0120.1',
#        'homer-M01126', 'homer-M01146', 'jaspar-PH0010.1',
#        'jaspar-PH0030.1', 'homer-M01251', 'jaspar-PH0135.1',
#        'taipale-NTGMATAATTAATGAN-POU4F3-DBD', 'homer-M00754',
#        'homer-M00788', 'homer-M00790', 'homer-M00825', 'tfdimers-MD00559',
#        'stark-GCTNMTTAA', 'homer-M00532', 'taipale-NYMATTAN-NKX6-1-full',
#        'yetfasco-1517', 'homer-M00476', 'homer-M00728', 'homer-M00729',
#        'homer-M00731', 'homer-M00793', 'homer-M00803', 'yetfasco-1453',
#        'homer-M00439', 'yetfasco-620', 'homer-M01276', 'jaspar-PH0160.1',
#        'homer-M01235', 'jaspar-PH0119.1', 'homer-M00763', 'homer-M00802',
#        'homer-M00674', 'yetfasco-727', 'yetfasco-875',
#        'taipale-NYMATTAN-NKX6-1-DBD', 'homer-M00436', 'homer-M00504',
#        'homer-M00772', 'homer-M01275', 'jaspar-PH0159.1', 'homer-M01716',
#        'jaspar-MA0416.1', 'yetfasco-561', 'yetfasco-819', 'homer-M00463',
#        'homer-M00485', 'homer-M00505', 'homer-M00528',
#        'stark-TAATTRANNTTNATG', 'homer-M01117', 'jaspar-PH0001.1',
#        'homer-M00732', 'iDMMPMM-ANTP', 'tfdimers-MD00022',
#        'taipale-NTAATTAN-LMX1A-DBD', 'tiffin-TIFDMEM0000004',
#        'homer-M00450', 'homer-M00466', 'homer-M00520', 'homer-M00550',
#        'homer-M01144', 'jaspar-PH0028.1', 'tfdimers-MD00243',
#        'homer-M01186', 'jaspar-PH0070.1', 'homer-M00781', 'yetfasco-1004',
#        'jaspar-PF0161.1', 'homer-M00738', 'homer-M00761',
#        'jaspar-CN0134.1', 'yetfasco-2073',
#        'taipale-NRTTACGTAAYN-DBP-full', 'homer-M00481', 'homer-M00498',
#        'homer-M00741', 'homer-M00748', 'homer-M00755', 'homer-M00797',
#        'homer-M00939', 'jaspar-PB0031.1', 'yetfasco-2110',
#        'jaspar-PF0026.1', 'homer-M00477', 'homer-M00727', 'homer-M00750',
#        'homer-M00809', 'homer-M00823', 'jaspar-MA0455.1',
#        'jaspar-PF0064.1', 'yetfasco-2056', 'homer-M00519', 'homer-M01417',
#        'stark-ATTNWTTA', 'tfdimers-MD00002', 'homer-M01171',
#        'homer-M01178', 'jaspar-PH0055.1', 'jaspar-PH0062.1',
#        'homer-M00700', 'homer-M00442', 'homer-M00455',
#        'taipale-NYTAATTARN-LHX6-full', 'yetfasco-624', 'homer-M01247',
#        'jaspar-PH0131.1', 'homer-M01215', 'homer-M01270',
#        'jaspar-PH0099.1', 'jaspar-PH0154.1', 'homer-M01136',
#        'jaspar-PH0020.1', 'homer-M00527', 'yetfasco-1345', 'homer-M01259',
#        'jaspar-PH0143.1', 'homer-M01187', 'jaspar-PH0071.1',
#        'taipale-NYAATTAN-ISX-full', 'jaspar-PF0084.1', 'hdpi-HDAC8',
#        'homer-M00460', 'homer-M00465', 'homer-M00479', 'homer-M00499',
#        'taipale-SCTMATTANN-POU6F2-full', 'homer-M00495', 'iDMMPMM-DFD',
#        'yetfasco-1479', 'yetfasco-1580',
#        'taipale-GTTAATNATTAAY-HNF1B-full', 'homer-M00722', 'homer-M00458',
#        'iDMMPMM-ABD_B', 'yetfasco-1129', 'taipale-NCCCCCCCAC-ZNF740-full',
#        'swissregulon-MAZ.p2', 'taipale-NCCCCCCCAC-ZNF740-DBD',
#        'taipale-GACCMCCYRMTGNGN-Zic3-DBD', 'homer-M00108',
#        'jaspar-PF0024.1', 'transfac_public-M00491',
#        'wolfe-Sug_F3-5-2_SOLEXA_5', 'taipale-GACCCCCCGCGNNG-GLIS3-DBD',
#        'yetfasco-1047', 'yetfasco-1247',
#        'taipale-GACCCCCYGYTGNGN-ZIC3-full',
#        'taipale-NNMCGCCCMCTCANNN-Egr1-mouse', 'homer-M00918',
#        'jaspar-PB0010.1', 'homer-M01005', 'jaspar-PB0097.1',
#        'jaspar-CN0067.1', 'homer-M01346', 'jaspar-MA0075.1',
#        'jaspar-CN0088.1', 'homer-M00513', 'homer-M00482',
#        'transfac_public-M00241', 'elemento-TTAATTGC', 'homer-M00457',
#        'stark-YAATKAAGY', 'homer-M00664', 'homer-M01122',
#        'jaspar-PH0006.1', 'tiffin-TIFDMEM0000032', 'homer-M00701',
#        'tiffin-TIFDMEM0000113', 'homer-M01224', 'jaspar-PH0108.1',
#        'homer-M00514', 'tiffin-TIFDMEM0000072', 'homer-M00433',
#        'taipale-NYAATTAN-ISX-DBD', 'homer-M00473',
#        'taipale-NYAATTAN-MSX2-DBD', 'yetfasco-1053',
#        'taipale-NYAATTAN-Msx3-DBD', 'iDMMPMM-EN', 'homer-M00452',
#        'homer-M00500', 'homer-M00752',
#        'taipale-NYAATTAAAANNYAATTA-MSX2-DBD', 'homer-M01191',
#        'jaspar-PH0075.1', 'swissregulon-NKX2-3_NKX2-5.p2',
#        'taipale-NYAATTAN-SHOX-DBD', 'taipale-NYAATTAN-Shox2-DBD',
#        'homer-M00608', 'taipale-NYMATAAAN-CDX2-DBD', 'homer-M00723',
#        'jaspar-PF0102.1', 'yetfasco-1171', 'homer-M01849', 'yetfasco-774',
#        'homer-M01554', 'yetfasco-709', 'homer-M01724', 'jaspar-MA0424.1',
#        'yetfasco-512', 'yetfasco-1145', 'yetfasco-844', 'homer-M01660',
#        'jaspar-MA0360.1', 'yetfasco-510', 'jaspar-PF0157.1',
#        'homer-M00333', 'yetfasco-1578', 'yetfasco-1577',
#        'jaspar-PF0103.1', 'yetfasco-2105',
#        'taipale-TAGAYRAYTGMCANGAA-ZNF713-full',
#        'taipale-NNCATCCCATAATANTC-ZNF410-DBD', 'yetfasco-1317',
#        'yetfasco-1304', 'taipale-NNAAAGGGTTAAW-Zfp652-DBD',
#        'jaspar-PF0112.1', 'yetfasco-1025', 'homer-M00335',
#        'selexconsensus-Hr46', 'homer-M00211', 'homer-M01839',
#        'yetfasco-1162', 'homer-M01620', 'jaspar-MA0320.1',
#        'yetfasco-1202', 'yetfasco-1272'], dtype=object)

# %%
tomtom_anno = tomtom_anno.dropna()
tomtom_anno
# Out:
#                                           Target_ID   q-value  \
# Query_ID
# Motif_0                taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_0                taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_7    flyfactorsurvey-sqz_SOLEXA_5_FBgn0010768  0.007039
# Motif_7    flyfactorsurvey-sqz_SOLEXA_5_FBgn0010768  0.007039
# Motif_7    flyfactorsurvey-sqz_SOLEXA_5_FBgn0010768  0.007039
# ...                                             ...       ...
# Motif_125       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.075995
# Motif_125               taipale-NNCCGCCATNW-YY2-DBD  0.094071
# Motif_127       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
#
#                                  motif_name gene_name
# Query_ID
# Motif_0           FOXK1_DBD_CGGACACAAT_repr      FoxK
# Motif_0           FOXK1_DBD_CGGACACAAT_repr      slp1
# Motif_7            sqz_SOLEXA_5_FBgn0010768      FoxP
# Motif_7            sqz_SOLEXA_5_FBgn0010768      dati
# Motif_7            sqz_SOLEXA_5_FBgn0010768        rn
# ...                                     ...       ...
# Motif_125  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets97D
# Motif_125          YY2_DBD_NNCCGCCATNW_repr       pho
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr     Atac3
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets21C
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets97D
#
# [5386 rows x 4 columns]

# %%
tomtom_anno['Query_ID'] = tomtom_anno.index
tomtom_anno
# Out:
# /home/ggj/anaconda3/envs/pytorch-cuda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                           Target_ID   q-value  \
# Query_ID
# Motif_0                taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_0                taipale-CGGACACAAT-FOXK1-DBD  0.080489
# Motif_7    flyfactorsurvey-sqz_SOLEXA_5_FBgn0010768  0.007039
# Motif_7    flyfactorsurvey-sqz_SOLEXA_5_FBgn0010768  0.007039
# Motif_7    flyfactorsurvey-sqz_SOLEXA_5_FBgn0010768  0.007039
# ...                                             ...       ...
# Motif_125       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.075995
# Motif_125               taipale-NNCCGCCATNW-YY2-DBD  0.094071
# Motif_127       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
# Motif_127       taipale-NACTTCCGSCGGAARMN-ELK1-full  0.096370
#
#                                  motif_name gene_name   Query_ID
# Query_ID
# Motif_0           FOXK1_DBD_CGGACACAAT_repr      FoxK    Motif_0
# Motif_0           FOXK1_DBD_CGGACACAAT_repr      slp1    Motif_0
# Motif_7            sqz_SOLEXA_5_FBgn0010768      FoxP    Motif_7
# Motif_7            sqz_SOLEXA_5_FBgn0010768      dati    Motif_7
# Motif_7            sqz_SOLEXA_5_FBgn0010768        rn    Motif_7
# ...                                     ...       ...        ...
# Motif_125  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets97D  Motif_125
# Motif_125          YY2_DBD_NNCCGCCATNW_repr       pho  Motif_125
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr     Atac3  Motif_127
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets21C  Motif_127
# Motif_127  ELK1_full_NACTTCCGSCGGAARMN_repr    Ets97D  Motif_127
#
# [5386 rows x 5 columns]

# %%
tomtom_anno.to_csv("./filter_anno.csv")

# %%
d = {}
for _, gene in tomtom_anno[["Query_ID", "gene_name"]].iterrows():
    m = gene.Query_ID
    tf = gene.gene_name
    if m not in d.keys():
        d[m] = [tf]
    else:
        tfs = d[m]
        if tf not in tfs:
            d[m].append(tf)

d["Motif_0"]
# Out:
# ['FoxK', 'slp1']

# %%
for k,v in d.items():
    d[k] = '; '.join(v)

d["Motif_0"]
# Out:
# 'FoxK; slp1'

# %%
filter_tf_anno = pd.DataFrame(d, index=['tfs']).T
filter_tf_anno.to_csv("./filter_tf_anno.csv")
filter_tf_anno
# Out:
#                                                          tfs
# Motif_0                                           FoxK; slp1
# Motif_7           FoxP; dati; rn; sqz; jim; hb; Aef1; CG4360
# Motif_8                                          Ets97D; pho
# Motif_12                                      nub; pdm2; vvl
# Motif_15                                                 tll
# Motif_19                                          E2f1; zfh1
# Motif_20                           pho; rn; sqz; NFAT; Rrp40
# Motif_22                                             rn; sqz
# Motif_23                                 nub; pdm2; vvl; exd
# Motif_26                               Atac3; Ets21C; Ets97D
# Motif_28   foxo; pho; EcR; Hnf4; Hr51; Hr78; svp; usp; So...
# Motif_30   E2f2; E2f1; Dp; Rbf; Rbf2; CG13775; Chd1; pnt;...
# Motif_31           aop; Eip74EF; Ets21C; Ets96B; Ets97D; pnt
# Motif_32                            hb; jim; FoxP; dati; sqz
# Motif_33                          CG7834; MED30; Atf6; CrebA
# Motif_37                                            jim; pnt
# Motif_39   retn; tj; Jra; kay; CG34031; FoxP; dati; rn; s...
# Motif_40   Hnf4; svp; tll; Hr78; usp; ERR; ftz-f1; Hr39; ...
# Motif_42          slp1; Abd-B; cad; Mef2; rump; Sox100B; Tbp
# Motif_44                             E2f1; ewg; ci; lmd; sug
# Motif_49   zfh1; E2f1; CrebB; grn; pnr; CG5846; CG9727; R...
# Motif_54   tj; nau; ac; ase; l(1)sc; sc; pho; hth; Myc; e...
# Motif_55                  FoxP; dati; rn; sqz; jim; hb; Mef2
# Motif_56   Chrac-14; Nf-YA; Nf-YB; Nf-YC; kay; exd; yps; ...
# Motif_61                         foxo; pho; Ets97D; EcR; usp
# Motif_62                                        Aef1; CG4360
# Motif_63                                       E2f1; oc; grn
# Motif_64                                CG6769; CG10348; ham
# Motif_66                                  pho; rn; sqz; NFAT
# Motif_72                                 FoxP; dati; rn; sqz
# Motif_73   Jra; kay; retn; FoxP; dati; rn; sqz; tj; croc;...
# Motif_74   Eip74EF; Spps; CG7834; Stat92E; pnt; Pur-alpha...
# Motif_76                                              Ets21C
# Motif_78   pho; rn; sqz; retn; tj; zfh1; foxo; Ptx1; slp1...
# Motif_79                                           E2f1; vvl
# Motif_82   foxo; pho; pan; Abd-B; tHMG1; tHMG2; croc; slp...
# Motif_85   FoxP; dati; sqz; hb; rn; jim; croc; fd64A; slp...
# Motif_87                        FoxP; dati; sqz; rn; jim; hb
# Motif_88                       ey; eyg; gsb; gsb-n; prd; toe
# Motif_89                           TfAP-2; crp; pnt; ovo; tj
# Motif_90                                                 cad
# Motif_93                   retn; TfAP-2; kn; Ptx1; nub; pdm2
# Motif_95   Abd-B; cad; CG4328; Lim1; Lim3; Lmx1a; PHDP; u...
# Motif_96                                                 jim
# Motif_98   SREBP; ci; lmd; sug; CG7368; Dp; cbt; crol; l(...
# Motif_99                     Abd-B; nub; pdm2; cad; EcR; usp
# Motif_101  Antp; Abd-B; tll; C15; Dbx; E5; HGTX; Lmx1a; U...
# Motif_106     Atac3; Ets21C; Ets97D; pnt; Sox100B; ovo; Ubc4
# Motif_107                    fd96Ca; fd96Cb; FoxK; slp1; nau
# Motif_110                       FoxP; dati; rn; sqz; jim; hb
# Motif_116                                  CG13775; Dp; E2f2
# Motif_125                    jim; Atac3; Ets21C; Ets97D; pho
# Motif_127                              Atac3; Ets21C; Ets97D

# %%
tomtom_anno.gene_name.unique()
# Out:
# array(['FoxK', 'slp1', 'FoxP', 'dati', 'rn', 'sqz', 'jim', 'hb', 'Aef1',
#        'CG4360', 'Ets97D', 'pho', 'nub', 'pdm2', 'vvl', 'tll', 'E2f1',
#        'zfh1', 'NFAT', 'Rrp40', 'exd', 'Atac3', 'Ets21C', 'foxo', 'EcR',
#        'Hnf4', 'Hr51', 'Hr78', 'svp', 'usp', 'Sox15', 'bbx', 'D', 'peng',
#        'Sox100B', 'Sox102F', 'Sox14', 'Sox21a', 'Sox21b', 'SoxN', 'E2f2',
#        'Dp', 'Rbf', 'Rbf2', 'CG13775', 'Chd1', 'pnt', 'crp', 'aop',
#        'Eip74EF', 'Ets96B', 'CG7834', 'MED30', 'Atf6', 'CrebA', 'retn',
#        'tj', 'Jra', 'kay', 'CG34031', 'B-H2', 'CG9876', 'Hmx', 'lms',
#        'ERR', 'ftz-f1', 'Hr39', 'Hr38', 'Stat92E', 'Hr4', 'dsf', 'bi',
#        'byn', 'Doc2', 'H15', 'mid', 'org-1', 'CG5641', 'srl', 'Abd-B',
#        'cad', 'Mef2', 'rump', 'Tbp', 'ewg', 'ci', 'lmd', 'sug', 'CrebB',
#        'grn', 'pnr', 'CG5846', 'CG9727', 'Rfx', 'nau', 'ac', 'ase',
#        'l(1)sc', 'sc', 'hth', 'Myc', 'esg', 'da', 'wor', 'HLH4C', 'sna',
#        'Chrac-14', 'Nf-YA', 'Nf-YB', 'Nf-YC', 'yps', 'CG7839', 'Mes4',
#        'oc', 'CG6769', 'CG10348', 'ham', 'croc', 'fd64A', 'NfI', 'pan',
#        'onecut', 'Spps', 'Pur-alpha', 'CG14718', 'caz', 'scro', 'Ptx1',
#        'Awh', 'tHMG1', 'tHMG2', 'bin', 'fd59A', 'fkh', 'Taf7', 'Mad',
#        'fd96Ca', 'fd96Cb', 'ey', 'eyg', 'gsb', 'gsb-n', 'prd', 'toe',
#        'TfAP-2', 'ovo', 'kn', 'CG4328', 'Lim1', 'Lim3', 'Lmx1a', 'PHDP',
#        'unc-4', 'CG11294', 'CG18599', 'CG32532', 'Dfd', 'E5', 'Pph13',
#        'Rx', 'Traf4', 'Vsx1', 'ap', 'en', 'lab', 'otp', 'repo', 'ro',
#        'unpg', 'Drgx', 'al', 'CG34367', 'ems', 'zfh2', 'slou', 'Ubx',
#        'Vsx2', 'abd-A', 'hbn', 'inv', 'lbl', 'Antp', 'C15', 'Dbx', 'HGTX',
#        'ftz', 'zen2', 'ind', 'Scr', 'bsh', 'btn', 'eve', 'pb', 'zen',
#        'cnc', 'OdsH', 'exex', 'bap', 'CG7745', 'lbe', 'toy', 'H2.0',
#        'Dll', 'Dr', 'acj6', 'HHEX', 'Optix', 'pdm3', 'CG15696', 'NK7.1',
#        'tup', 'CG7786', 'gt', 'hng1', 'Pdp1', 'vri', 'CG11085', 'SREBP',
#        'CG7368', 'cbt', 'crol', 'l(3)neo38', 'opa', 'CstF-64', 'pont',
#        'Ubc4'], dtype=object)
